# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:0bc2a451-fbce-490f-96ca-49f475ae9d16.png)

# %%
### 将图像转换为numpy数组,获取的时像素值
from matplotlib.image import imread
panda  = imread("../images/numpy-panda.jpeg")
panda.dtype
# Out:
# dtype('uint8')

# %%
panda.size
# Out:
# 3271680

# %%
panda.shape
# Out:
# (852, 1280, 3)
